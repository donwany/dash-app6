# %%
import pandas as pd

df = pd.read_csv('/opt/app/omni-machine-learning/Model_DRF/train/data/case_withApplication_forTraining.csv',low_memory=False)

# %%
df.head()
# Out:
#    avertackCase.distinctFieldCountsMap.state avertackCase.status  \
# 0                                        1.0                 New
# 1                                        1.0                 New
# 2                                        1.0                 New
# 3                                        1.0                 New
# 4                                        1.0                 New
#
#    avertackCase.distinctFieldCountsMap.salesChannel  avertackCase.referred  \
# 0                                               1.0                  False
# 1                                               1.0                  False
# 2                                               1.0                  False
# 3                                               1.0                  False
# 4                                               1.0                  False
#
#   avertackCase.caseApplicationRecordList.banStatus  avertackCase.hotCustomer  \
# 0                                             Open                     False
# 1                                        Tentative                     False
# 2                                        Tentative                     False
# 3                                        Tentative                     False
# 4                                        Tentative                     False
#
#    avertackCase.caseApplicationRecordList.applicationRecord.applicationTimeStamp.$date  \
# 0                                      1535757621000
# 1                                      1535765504000
# 2                                      1535767193000
# 3                                      1535766569000
# 4                                      1535769064000
#
#    avertackCase.maxAppLimitReached  avertackCase.createdDateTime.$date  \
# 0                            False                       1535772691509
# 1                            False                       1535772691509
# 2                            False                       1535772691509
# 3                            False                       1535772691509
# 4                            False                       1535773877666
#
#    avertackCase.rt         ...           \
# 0            False         ...
# 1            False         ...
# 2            False         ...
# 3            False         ...
# 4            False         ...
#
#   avertackCase.caseApplicationRecordList.hotTagMap.Email  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    avertackCase.caseApplicationRecordList.hotTagMap.NameDob  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    avertackCase.caseApplicationRecordList.hotTagMap.PersistentKey  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   avertackCase.distinctFieldCountsMap.authorizedName  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   avertackCase.caseApplicationRecordList.applicationRecord.fields.authorizedName  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   avertackCase.caseApplicationRecordList.hotTagMap.SSN  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    avertackCase.caseApplicationRecordList.hotTagMap.Name  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   avertackCase.caseApplicationRecordList.applicationRecord.lastUpdateDateTime.$date  \
# 0                                       1.535768e+12
# 1                                       1.535769e+12
# 2                                       1.535771e+12
# 3                                       1.535770e+12
# 4                                       1.535769e+12
#
#   avertackCase.caseApplicationRecordList.hotTagMap.NameAddress  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    avertackCase.parent
# 0                  NaN
# 1                  NaN
# 2                  NaN
# 3                  NaN
# 4                  NaN
#
# [5 rows x 97 columns]

# %%
df.columns
# Out:
# Index([u'avertackCase.distinctFieldCountsMap.state', u'avertackCase.status',
#        u'avertackCase.distinctFieldCountsMap.salesChannel',
#        u'avertackCase.referred',
#        u'avertackCase.caseApplicationRecordList.banStatus',
#        u'avertackCase.hotCustomer',
#        u'avertackCase.caseApplicationRecordList.applicationRecord.applicationTimeStamp.$date',
#        u'avertackCase.maxAppLimitReached',
#        u'avertackCase.createdDateTime.$date', u'avertackCase.rt',
#        u'avertackCase.caseApplicationRecordList.applicationRecord.fields.primaryAddress',
#        u'avertackCase.caseApplicationRecordList.applicationRecord.fields.requestedLines',
#        u'avertackCase.distinctFieldCountsMap.ban',
#        u'avertackCase.caseApplicationRecordList.applicationRecord.fields.customerType',
#        u'avertackCase.rules',
#        u'avertackCase.caseApplicationRecordList.applicationRecord.fields.state',
#        u'avertackCase.caseApplicationRecordList.applicationRecord.fields.authorizedPhoneNum',
#        u'avertackCase.caseApplicationRecordList.applicationRecord.fields.salesChannel',
#        u'avertackCase.caseApplicationRecordList.mobileCustomerRefDate',
#        u'avertackCase.lastApplicationDateTime.$date',
#        u'avertackCase.distinctFieldCountsMap.requestedLines',
#        u'avertackCase.distinctFieldCountsMap.primaryAddress',
#        u'avertackCase.caseApplicationRecordList.isHotCustomer',
#        u'avertackCase.distinctFieldCountsMap.affiliateId',
#        u'avertackCase.caseApplicationRecordList.applicationRecord.fields.zip',
#        u'avertackCase.distinctFieldCountsMap.applStoreID',
#        u'avertackCase.distinctFieldCountsMap.businessName',
#        u'avertackCase.firstApplicationDateTime.$date', u'avertackCase.apt',
#        u'avertackCase.distinctFieldCountsMap.dealerCodeOrAttId',
#        u'avertackCase.caseApplicationRecordList.referred',
#        u'avertackCase.caseApplicationRecordList.isApplicationLocked',
#        u'avertackCase.distinctFieldCountsMap.persistentKey',
#        u'avertackCase.caseApplicationRecordList.applicationRecord.fields.email',
#        u'avertackCase.caseApplicationRecordList.applicationRecord._id',
#        u'avertackCase.distinctFieldCountsMap.authorizedPhoneNum',
#        u'avertackCase.caseApplicationRecordList.applicationRecord.fields.businessName',
#        u'avertackCase.caseApplicationRecordList.applicationRecord.fields.ban',
#        u'avertackCase.caseApplicationRecordList.applicationRecord.fields.taxId',
#        u'avertackCase.caseApplicationRecordList.applicationRecord.fields.dealerCodeOrAttId',
#        u'avertackCase.manualCase',
#        u'avertackCase.caseApplicationRecordList.applicationRecord.fields.city',
#        u'avertackCase.distinctFieldCountsMap.customerType',
#        u'avertackCase.caseApplicationRecordList.applicationRecord.fields.persistentKey',
#        u'avertackCase._id',
#        u'avertackCase.caseApplicationRecordList.applicationRecord.createdDateTime.$date',
#        u'avertackCase._class',
#        u'avertackCase.distinctFieldCountsMap.primaryAddressStreetName',
#        u'avertackCase.distinctFieldCountsMap.taxId',
#        u'avertackCase.distinctFieldCountsMap.applicationId',
#        u'avertackCase.caseApplicationRecordList.applicationRecord.serviceId',
#        u'avertackCase.rulesStr', u'avertackCase.lastUpdatedUser',
#        u'avertackCase.caseApplicationRecordList.isReAlert',
#        u'avertackCase.lastUpdateDateTime.$date',
#        u'avertackCase.distinctFieldCountsMap.market',
#        u'avertackCase.caseApplicationRecordList.applicationRecord.fields.primaryAddressStreetName',
#        u'avertackCase.version', u'avertackCase.distinctFieldCountsMap.email',
#        u'avertackCase.distinctFieldCountsMap.city',
#        u'avertackCase.caseApplicationRecordList.hotCustomer',
#        u'avertackCase.keyField',
#        u'avertackCase.caseApplicationRecordList.applicationRecord.fields.market',
#        u'avertackCase.distinctFieldCountsMap.zip',
#        u'avertackCase.caseApplicationRecordList.applicationRecord.fields.affiliateId',
#        u'avertackCase.caseApplicationRecordList.applicationRecord.fields.applStoreID',
#        u'avertackCase.distinctFieldCountsMap.dob',
#        u'avertackCase.distinctFieldCountsMap.SSN',
#        u'avertackCase.distinctFieldCountsMap.submarket',
#        u'avertackCase.caseApplicationRecordList.applicationRecord.fields.firstName',
#        u'avertackCase.caseApplicationRecordList.applicationRecord.fields.submarket',
#        u'avertackCase.caseApplicationRecordList.applicationRecord.fields.SSN',
#        u'avertackCase.caseApplicationRecordList.applicationRecord.fields.dob',
#        u'avertackCase.distinctFieldCountsMap.firstName',
#        u'avertackCase.distinctFieldCountsMap.lastName',
#        u'avertackCase.caseApplicationRecordList.applicationRecord.fields.lastName',
#        u'avertackCase.distinctFieldCountsMap.middleInitial',
#        u'avertackCase.caseApplicationRecordList.applicationRecord.fields.middleInitial',
#        u'avertackCase.caseApplicationRecordList.applicationRecord.fields.secondaryAddress',
#        u'avertackCase.distinctFieldCountsMap.secondaryAddress',
#        u'avertackCase.caseNoteList.name',
#        u'avertackCase.caseNoteList.attUserId', u'avertackCase.caseDisposition',
#        u'avertackCase.caseNoteList.createDateTime.$date',
#        u'avertackCase.manager', u'avertackCase.caseNoteList.content',
#        u'avertackCase.caseApplicationRecordList.hotTagMap.Address',
#        u'avertackCase.caseApplicationRecordList.hotTagMap.Email',
#        u'avertackCase.caseApplicationRecordList.hotTagMap.NameDob',
#        u'avertackCase.caseApplicationRecordList.hotTagMap.PersistentKey',
#        u'avertackCase.distinctFieldCountsMap.authorizedName',
#        u'avertackCase.caseApplicationRecordList.applicationRecord.fields.authorizedName',
#        u'avertackCase.caseApplicationRecordList.hotTagMap.SSN',
#        u'avertackCase.caseApplicationRecordList.hotTagMap.Name',
#        u'avertackCase.caseApplicationRecordList.applicationRecord.lastUpdateDateTime.$date',
#        u'avertackCase.caseApplicationRecordList.hotTagMap.NameAddress',
#        u'avertackCase.parent'],
#       dtype='object')

# %%
import dash
import dash_core_components as dcc
import dash_html_components as html
import pandas as pd
import plotly.plotly as py
import plotly.graph_objs as go
import plotly.figure_factory as ff

from plotly.tools import FigureFactory as FF

app = dash.Dash()

df = pd.read_csv('/opt/app/omni-machine-learning/Model_DRF/train/data/case_withApplication_forTraining.csv',low_memory=False)

table = FF.create_table(df)
